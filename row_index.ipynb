# %%
import numpy as np
from combinations import compositions, bounded_compositions
from multiperms import multinomial

# %% [markdown]
# Всевозможные строки факторной матрицы образуют разбиения числа $n=0, \ldots, 8$ на $3$ части. При фиксированном $n$ есть $\binom{n+2}2$ таких композиций, всего получается
# $$
#     \binom 22 + \binom 32 + \ldots + \binom{10} 2 = \binom {11}3 = \frac{11 \cdot 10 \cdot 9}{6} = 11 \cdot 15 = 165.
# $$
#
# Каждой композиции $n = n_1 + n_2 + n_3$ соответствует $\binom{n}{n_1, n_2, n_3} = \frac{n!}{n_1!n_2!n_3!}$ раскладов. При фиксированном $n$ их число равно $3^n$ (обобщённый бином Ньютона), поэтому всего раскладов
# $$
# 1 + 3 + 9 + 27 + 81 + 243 + 729 + 2087 + 6561 = \frac{3^9 - 1}2 = 9841.
# $$
#
# Таким образом, для индексации раскладов одной масти достаточно $14$ бит, всех мастей — $14\cdot 4 = 56$ бит. Отлично помещается в $64$-битный int, и ещё 8 бит остаётся в резерве.

# %%
def row_indexing(n_parts, max_sum, verbose=True):
    total_deals = 0
    comp2index = {}
    index2comp = {}
    for sum in range(max_sum + 1):
        if verbose:
            print(f"Sum {sum} begins at index {total_deals}")
        for comp in compositions(sum, n_parts):
            print(f"Composition {comp} with {multinomial(comp)} deals begins at index {total_deals}")
            index2comp[total_deals] = tuple(comp)
            comp2index[tuple(comp)] = total_deals
            total_deals += multinomial(comp)
    print("Total deals:", total_deals, np.logspace(0, max_sum, num=max_sum + 1, base=n_parts).sum())
    return comp2index, index2comp

def random_index(comp2index, comp):
    return comp2index[comp] + np.random.randint(multinomial(comp))

# %%
comp2index, index2comp = row_indexing(3, 8)
# Out:
# Sum 0 begins at index 0
# Composition [0 0 0] with 1 deals begins at index 0
# Sum 1 begins at index 1
# Composition [1 0 0] with 1 deals begins at index 1
# Composition [0 1 0] with 1 deals begins at index 2
# Composition [0 0 1] with 1 deals begins at index 3
# Sum 2 begins at index 4
# Composition [2 0 0] with 1 deals begins at index 4
# Composition [1 1 0] with 2 deals begins at index 5
# Composition [0 2 0] with 1 deals begins at index 7
# Composition [1 0 1] with 2 deals begins at index 8
# Composition [0 1 1] with 2 deals begins at index 10
# Composition [0 0 2] with 1 deals begins at index 12
# Sum 3 begins at index 13
# Composition [3 0 0] with 1 deals begins at index 13
# Composition [2 1 0] with 3 deals begins at index 14
# Composition [1 2 0] with 3 deals begins at index 17
# Composition [0 3 0] with 1 deals begins at index 20
# Composition [2 0 1] with 3 deals begins at index 21
# Composition [1 1 1] with 6 deals begins at index 24
# Composition [0 2 1] with 3 deals begins at index 30
# Composition [1 0 2] with 3 deals begins at index 33
# Composition [0 1 2] with 3 deals begins at index 36
# Composition [0 0 3] with 1 deals begins at index 39
# Sum 4 begins at index 40
# Composition [4 0 0] with 1 deals begins at index 40
# Composition [3 1 0] with 4 deals begins at index 41
# Composition [2 2 0] with 6 deals begins at index 45
# Composition [1 3 0] with 4 deals begins at index 51
# Composition [0 4 0] with 1 deals begins at index 55
# Composition [3 0 1] with 4 deals begins at index 56
# Composition [2 1 1] with 12 deals begins at index 60
# Composition [1 2 1] with 12 deals begins at index 72
# Composition [0 3 1] with 4 deals begins at index 84
# Composition [2 0 2] with 6 deals begins at index 88
# Composition [1 1 2] with 12 deals begins at index 94
# Composition [0 2 2] with 6 deals begins at index 106
# Composition [1 0 3] with 4 deals begins at index 112
# Composition [0 1 3] with 4 deals begins at index 116
# Composition [0 0 4] with 1 deals begins at index 120
# Sum 5 begins at index 121
# Composition [5 0 0] with 1 deals begins at index 121
# Composition [4 1 0] with 5 deals begins at index 122
# Composition [3 2 0] with 10 deals begins at index 127
# Composition [2 3 0] with 10 deals begins at index 137
# Composition [1 4 0] with 5 deals begins at index 147
# Composition [0 5 0] with 1 deals begins at index 152
# Composition [4 0 1] with 5 deals begins at index 153
# Composition [3 1 1] with 20 deals begins at index 158
# Composition [2 2 1] with 30 deals begins at index 178
# Composition [1 3 1] with 20 deals begins at index 208
# Composition [0 4 1] with 5 deals begins at index 228
# Composition [3 0 2] with 10 deals begins at index 233
# Composition [2 1 2] with 30 deals begins at index 243
# Composition [1 2 2] with 30 deals begins at index 273
# Composition [0 3 2] with 10 deals begins at index 303
# Composition [2 0 3] with 10 deals begins at index 313
# Composition [1 1 3] with 20 deals begins at index 323
# Composition [0 2 3] with 10 deals begins at index 343
# Composition [1 0 4] with 5 deals begins at index 353
# Composition [0 1 4] with 5 deals begins at index 358
# Composition [0 0 5] with 1 deals begins at index 363
# Sum 6 begins at index 364
# Composition [6 0 0] with 1 deals begins at index 364
# Composition [5 1 0] with 6 deals begins at index 365
# Composition [4 2 0] with 15 deals begins at index 371
# Composition [3 3 0] with 20 deals begins at index 386
# Composition [2 4 0] with 15 deals begins at index 406
# Composition [1 5 0] with 6 deals begins at index 421
# Composition [0 6 0] with 1 deals begins at index 427
# Composition [5 0 1] with 6 deals begins at index 428
# Composition [4 1 1] with 30 deals begins at index 434
# Composition [3 2 1] with 60 deals begins at index 464
# Composition [2 3 1] with 60 deals begins at index 524
# Composition [1 4 1] with 30 deals begins at index 584
# Composition [0 5 1] with 6 deals begins at index 614
# Composition [4 0 2] with 15 deals begins at index 620
# Composition [3 1 2] with 60 deals begins at index 635
# Composition [2 2 2] with 90 deals begins at index 695
# Composition [1 3 2] with 60 deals begins at index 785
# Composition [0 4 2] with 15 deals begins at index 845
# Composition [3 0 3] with 20 deals begins at index 860
# Composition [2 1 3] with 60 deals begins at index 880
# Composition [1 2 3] with 60 deals begins at index 940
# Composition [0 3 3] with 20 deals begins at index 1000
# Composition [2 0 4] with 15 deals begins at index 1020
# Composition [1 1 4] with 30 deals begins at index 1035
# Composition [0 2 4] with 15 deals begins at index 1065
# Composition [1 0 5] with 6 deals begins at index 1080
# Composition [0 1 5] with 6 deals begins at index 1086
# Composition [0 0 6] with 1 deals begins at index 1092
# Sum 7 begins at index 1093
# Composition [7 0 0] with 1 deals begins at index 1093
# Composition [6 1 0] with 7 deals begins at index 1094
# Composition [5 2 0] with 21 deals begins at index 1101
# Composition [4 3 0] with 35 deals begins at index 1122
# Composition [3 4 0] with 35 deals begins at index 1157
# Composition [2 5 0] with 21 deals begins at index 1192
# Composition [1 6 0] with 7 deals begins at index 1213
# Composition [0 7 0] with 1 deals begins at index 1220
# Composition [6 0 1] with 7 deals begins at index 1221
# Composition [5 1 1] with 42 deals begins at index 1228
# Composition [4 2 1] with 105 deals begins at index 1270
# Composition [3 3 1] with 140 deals begins at index 1375
# Composition [2 4 1] with 105 deals begins at index 1515
# Composition [1 5 1] with 42 deals begins at index 1620
# Composition [0 6 1] with 7 deals begins at index 1662
# Composition [5 0 2] with 21 deals begins at index 1669
# Composition [4 1 2] with 105 deals begins at index 1690
# Composition [3 2 2] with 210 deals begins at index 1795
# Composition [2 3 2] with 210 deals begins at index 2005
# Composition [1 4 2] with 105 deals begins at index 2215
# Composition [0 5 2] with 21 deals begins at index 2320
# Composition [4 0 3] with 35 deals begins at index 2341
# Composition [3 1 3] with 140 deals begins at index 2376
# Composition [2 2 3] with 210 deals begins at index 2516
# Composition [1 3 3] with 140 deals begins at index 2726
# Composition [0 4 3] with 35 deals begins at index 2866
# Composition [3 0 4] with 35 deals begins at index 2901
# Composition [2 1 4] with 105 deals begins at index 2936
# Composition [1 2 4] with 105 deals begins at index 3041
# Composition [0 3 4] with 35 deals begins at index 3146
# Composition [2 0 5] with 21 deals begins at index 3181
# Composition [1 1 5] with 42 deals begins at index 3202
# Composition [0 2 5] with 21 deals begins at index 3244
# Composition [1 0 6] with 7 deals begins at index 3265
# Composition [0 1 6] with 7 deals begins at index 3272
# Composition [0 0 7] with 1 deals begins at index 3279
# Sum 8 begins at index 3280
# Composition [8 0 0] with 1 deals begins at index 3280
# Composition [7 1 0] with 8 deals begins at index 3281
# Composition [6 2 0] with 28 deals begins at index 3289
# Composition [5 3 0] with 56 deals begins at index 3317
# Composition [4 4 0] with 70 deals begins at index 3373
# Composition [3 5 0] with 56 deals begins at index 3443
# Composition [2 6 0] with 28 deals begins at index 3499
# Composition [1 7 0] with 8 deals begins at index 3527
# Composition [0 8 0] with 1 deals begins at index 3535
# Composition [7 0 1] with 8 deals begins at index 3536
# Composition [6 1 1] with 56 deals begins at index 3544
# Composition [5 2 1] with 168 deals begins at index 3600
# Composition [4 3 1] with 280 deals begins at index 3768
# Composition [3 4 1] with 280 deals begins at index 4048
# Composition [2 5 1] with 168 deals begins at index 4328
# Composition [1 6 1] with 56 deals begins at index 4496
# Composition [0 7 1] with 8 deals begins at index 4552
# Composition [6 0 2] with 28 deals begins at index 4560
# Composition [5 1 2] with 168 deals begins at index 4588
# Composition [4 2 2] with 420 deals begins at index 4756
# Composition [3 3 2] with 560 deals begins at index 5176
# Composition [2 4 2] with 420 deals begins at index 5736
# Composition [1 5 2] with 168 deals begins at index 6156
# Composition [0 6 2] with 28 deals begins at index 6324
# Composition [5 0 3] with 56 deals begins at index 6352
# Composition [4 1 3] with 280 deals begins at index 6408
# Composition [3 2 3] with 560 deals begins at index 6688
# Composition [2 3 3] with 560 deals begins at index 7248
# Composition [1 4 3] with 280 deals begins at index 7808
# Composition [0 5 3] with 56 deals begins at index 8088
# Composition [4 0 4] with 70 deals begins at index 8144
# Composition [3 1 4] with 280 deals begins at index 8214
# Composition [2 2 4] with 420 deals begins at index 8494
# Composition [1 3 4] with 280 deals begins at index 8914
# Composition [0 4 4] with 70 deals begins at index 9194
# Composition [3 0 5] with 56 deals begins at index 9264
# Composition [2 1 5] with 168 deals begins at index 9320
# Composition [1 2 5] with 168 deals begins at index 9488
# Composition [0 3 5] with 56 deals begins at index 9656
# Composition [2 0 6] with 28 deals begins at index 9712
# Composition [1 1 6] with 56 deals begins at index 9740
# Composition [0 2 6] with 28 deals begins at index 9796
# Composition [1 0 7] with 8 deals begins at index 9824
# Composition [0 1 7] with 8 deals begins at index 9832
# Composition [0 0 8] with 1 deals begins at index 9840
# Total deals: 9841 9841.0

# %%
random_index(comp2index, (1, 0, 3))
# Out:
# 113

# %% [markdown]
# Для удобного использования следует предусмотреть возможность случайного выбора расклада при известном размере масти или известном распределении размеров мастей по рукам.
